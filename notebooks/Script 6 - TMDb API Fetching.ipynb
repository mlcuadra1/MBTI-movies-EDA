# %%
import requests
import json
import urllib.request
import pandas as pd
import ast

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmMwMDBjMGE5YzZjZmNkMDYxYWIyN2EzMjA1YjM0NiIsInN1YiI6IjY2NDRlMzUzM2YwMGEzYTg5YjViZDFkMiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._E0exiVUWU6c_FyyCeGdqQpaOM_tFDreyWlV6bmclPk"
}

# %%
survey_responses_df = pd.read_csv('../data/Data 2 - Transformed Survey Responses.csv', encoding='unicode_escape')
# survey_responses_df.drop(columns='Unnamed: 0', inplace=True)
survey_responses_df
# Out:
#       id person_mbti         mbti_test         character  \
# 0      0        ENFP  michaelcaloz.com        Tony Stark
# 1      0        ENFP  michaelcaloz.com    Rocket Raccoon
# 2      0        ENFP  michaelcaloz.com   Captain America
# 3      0        ENFP  michaelcaloz.com      Peter Parker
# 4      0        ENFP  michaelcaloz.com       Hobie Brown
# ..   ...         ...               ...               ...
# 700  123        ENFP  michaelcaloz.com       Agent Smith
# 701  123        ENFP  michaelcaloz.com  Daniel Plainview
# 702  123        ENFP  michaelcaloz.com          The Baby
# 703  123        ENFP  michaelcaloz.com   Patrick Bateman
# 704  123        ENFP  michaelcaloz.com        Raoul Duke
#
#                                    movie
# 0                      Avengers: Endgame
# 1         Guardians of the Galaxy Vol. 3
# 2                      Avengers: Endgame
# 3              Spider-Man: Far From Home
# 4    Spider-Man: Across the Spider-Verse
# ...

# %%
movie_list = list(survey_responses_df['movie'])#[:10]

movie_dict_list = []
failed_list = []
for i, title in enumerate(movie_list):
    try:
        title_replace = title.replace(' ', '+')
        split_title = title_replace.split('+(', maxsplit=1)
        title_part = split_title[0]
        # print('split title okay:', split_title[0])
        year_part = split_title[1].replace(')', '')
        # print('year2 okay:', year_part)
        
        url = 'https://api.themoviedb.org/3/search/movie?query=' + title_part + '&year=' + year_part + '&api_key=cbc000c0a9c6cfcd061ab27a3205b346'
        
    except:
        url = 'https://api.themoviedb.org/3/search/movie?query=' + title + '&api_key=cbc000c0a9c6cfcd061ab27a3205b346'
    
    # print(str(url))
    print(i, split_title[0])

    try:
        response = requests.get(url, headers=headers)
        data = response.json()
        
        # While data above is a dictionary, it contains more dictionaries within it, so narrow down
        movie_data = data['results'][0]
        print(i, movie_data['title'])
        movie_dict_list.append(movie_data)
    except:
        failed_list.append(title)
        print('Failed', len(failed_list))
    print()
    
    survey_responses_df.at[i, 'new_title'] = movie_data['title']
survey_responses_df
# Out:
# 0 Avengers:+Endgame
# 0 Avengers: Endgame
#
# 1 Guardians+of+the+Galaxy+Vol.+3
# 1 Guardians of the Galaxy Vol. 3
#
# 2 Avengers:+Endgame
# 2 Avengers: Endgame
#
# 3 Spider-Man:+Far+From+Home
# 3 Spider-Man: Far From Home
#
# 4 Spider-Man:+Across+the+Spider-Verse
# 4 Spider-Man: Across the Spider-Verse
#
# 5 The+Amazing+Spider-Man
# 5 The Amazing Spider-Man
#
# 6 Before+Sunrise
# 6 Before Sunrise
#
# 7 Before+Sunrise
# 7 Before Sunrise
#
# 8 Poor+Things
# 8 Poor Things
#
# 9 Spider-Man:+Across+the+Spider-Verse
# 9 Spider-Man: Across the Spider-Verse
#
# 10 Johnny+English
# 10 Johnny English
#
# 11 Avengers:+Infinity+War
# 11 Avengers: Infinity War
#
# 12 Top+Gun:+Maverick
# 12 Top Gun: Maverick
#
# 13 The+Matrix
# 13 The Matrix
#
# 14 Ready+Player+One
# 14 Ready Player One
#
# 15 Glass+Onion:+A+Knives+Out+Mystery
# 15 Glass Onion: A Knives Out Mystery
#
# 16 Doctor+Strange
# 16 Doctor Strange
#
# 17 Oppenheimer
# 17 Oppenheimer
#
# 18 Puss+in+Boots:+The+Last+Wish
# ...

# %%
# movie_list = list('Mr. & Mrs. Smith (2005)')#[:10]
def movie_query(movie_list):
    extra_movie_dict_list = []
    extra_failed_list = []
    for i, title in enumerate(movie_list):
        try:
            title_replace = title.replace(' ', '+')
            split_title = title_replace.split('+(', maxsplit=1)
            title_part = split_title[0]
            # print('split title okay:', split_title[0])
            year_part = split_title[1].replace(')', '')
            # print('year2 okay:', year_part)
            
            url = 'https://api.themoviedb.org/3/search/movie?query=' + title_part + '&year=' + year_part + '&api_key=cbc000c0a9c6cfcd061ab27a3205b346'
            
        except:
            url = 'https://api.themoviedb.org/3/search/movie?query=' + title + '&api_key=cbc000c0a9c6cfcd061ab27a3205b346'
        
        # print(str(url))
        print(i, split_title[0])

        try:
            response = requests.get(url, headers=headers)
            data = response.json()
            
            # While data above is a dictionary, it contains more dictionaries within it, so narrow down
            movie_data = data['results'][0]
            print(i, movie_data['title'])
            extra_movie_dict_list.append(movie_data)
        except:
            extra_failed_list.append(title)
            print('Failed', len(extra_failed_list))
        print()

movie_query(['wall.e'])
# Out:
# 0 wall.e
# 0 WALL·E

# %%
movie_details_df = pd.DataFrame(data=movie_dict_list)
movie_details_df.drop(columns=['adult', 'backdrop_path', 'original_language', 'original_title', 'overview', 'poster_path', 'video'], inplace=True)
movie_details_df
# Out:
#              genre_ids      id  popularity release_date  \
# 0        [12, 878, 28]  299534     270.643   2019-04-24
# 1        [878, 12, 28]  447365     169.751   2023-05-03
# 2        [12, 878, 28]  299534     270.643   2019-04-24
# 3        [28, 12, 878]  429617      94.358   2019-06-28
# 4    [16, 28, 12, 878]  569094     192.243   2023-05-31
# ..                 ...     ...         ...          ...
# 699          [28, 878]     603     470.112   1999-03-31
# 700               [18]    7345      38.917   2007-12-26
# 701           [14, 27]     985      70.490   1978-02-03
# 702       [53, 18, 80]    1359      74.952   2000-04-13
# 703       [12, 18, 35]    1878      32.339   1998-05-19
#
#                                    title  vote_average  vote_count
# 0                      Avengers: Endgame         8.300       24916
# 1         Guardians of the Galaxy Vol. 3         7.972        6292
# 2                      Avengers: Endgame         8.300       24916
# ...

# %% [markdown]
# ## Merging survey responses and movie details

# %%
unique_movies = movie_details_df.drop_duplicates('title')
# unique_movies

# %%
movie_details_df.to_csv('../data/Data 5 - TMDb API movie details.csv')

# %%
response_details_merge = survey_responses_df.merge(unique_movies, how='left', left_on='new_title', right_on='title')

response_details_merge.to_csv('../data/Data 6 - Merged Responses and Movie Details.csv')
response_details_merge
# Out:
#      id_x person_mbti         mbti_test         character  \
# 0       0        ENFP  michaelcaloz.com        Tony Stark
# 1       0        ENFP  michaelcaloz.com    Rocket Raccoon
# 2       0        ENFP  michaelcaloz.com   Captain America
# 3       0        ENFP  michaelcaloz.com      Peter Parker
# 4       0        ENFP  michaelcaloz.com       Hobie Brown
# ..    ...         ...               ...               ...
# 700   123        ENFP  michaelcaloz.com       Agent Smith
# 701   123        ENFP  michaelcaloz.com  Daniel Plainview
# 702   123        ENFP  michaelcaloz.com          The Baby
# 703   123        ENFP  michaelcaloz.com   Patrick Bateman
# 704   123        ENFP  michaelcaloz.com        Raoul Duke
#
#                                    movie                            new_title  \
# 0                      Avengers: Endgame                    Avengers: Endgame
# 1         Guardians of the Galaxy Vol. 3       Guardians of the Galaxy Vol. 3
# ...

# %%
response_details_merge = pd.read_csv('../data/Data 6 - Merged Responses and Movie Details.csv')
response_details_merge.drop(columns=['Unnamed: 0', 'mbti_test', 'movie', 'title', 'vote_count'], inplace=True)

response_details_merge.rename(columns = {'id_x':'person_id', 'new_title':'movie', 'id_y':'movie_id', 'popularity':'movie_popularity', 'vote_average':'movie_vote_avg'}, inplace = True)
response_details_merge['movie_year'] = response_details_merge['release_date'].str[:4].astype(int)
response_details_merge.drop(columns = ['release_date'], inplace=True)

response_details_merge
# Out:
#      person_id person_mbti         character  \
# 0            0        ENFP        Tony Stark
# 1            0        ENFP    Rocket Raccoon
# 2            0        ENFP   Captain America
# 3            0        ENFP      Peter Parker
# 4            0        ENFP       Hobie Brown
# ..         ...         ...               ...
# 700        123        ENFP       Agent Smith
# 701        123        ENFP  Daniel Plainview
# 702        123        ENFP          The Baby
# 703        123        ENFP   Patrick Bateman
# 704        123        ENFP        Raoul Duke
#
#                                    movie          genre_ids  movie_id  \
# 0                      Avengers: Endgame      [12, 878, 28]    299534
# 1         Guardians of the Galaxy Vol. 3      [878, 12, 28]    447365
# 2                      Avengers: Endgame      [12, 878, 28]    299534
# 3              Spider-Man: Far From Home      [28, 12, 878]    429617
# ...

# %% [markdown]
# ## Adding MBTI

# %%
# url = "https://api.themoviedb.org/3/movie/346698/credits?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmMwMDBjMGE5YzZjZmNkMDYxYWIyN2EzMjA1YjM0NiIsInN1YiI6IjY2NDRlMzUzM2YwMGEzYTg5YjViZDFkMiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._E0exiVUWU6c_FyyCeGdqQpaOM_tFDreyWlV6bmclPk"
}
response = requests.get(url, headers=headers)

movie_id_list = [346698]

dict_list = []
for movie_id in movie_id_list:
    url = 'https://api.themoviedb.org/3/movie/' + str(movie_id) + '/credits?language=en-US'
    response = requests.get(url, headers=headers)
    data = response.json()
    cast_len = len(data['cast'])
    for cast in range(cast_len):
        print(data['cast'][cast])
# Out:
# {'adult': False, 'gender': 1, 'id': 234352, 'known_for_department': 'Acting', 'name': 'Margot Robbie', 'original_name': 'Margot Robbie', 'popularity': 94.207, 'profile_path': '/euDPyqLnuwaWMHajcU3oZ9uZezR.jpg', 'cast_id': 58, 'character': 'Barbie', 'credit_id': '5f88a9d28258fc0036ad14ff', 'order': 0}
# {'adult': False, 'gender': 2, 'id': 30614, 'known_for_department': 'Acting', 'name': 'Ryan Gosling', 'original_name': 'Ryan Gosling', 'popularity': 85.32, 'profile_path': '/lyUyVARQKhGxaxy0FbPJCQRpiaW.jpg', 'cast_id': 59, 'character': 'Ken', 'credit_id': '61732049a217c000434083ec', 'order': 1}
# {'adult': False, 'gender': 1, 'id': 59174, 'known_for_department': 'Acting', 'name': 'America Ferrera', 'original_name': 'America Ferrera', 'popularity': 36.649, 'profile_path': '/7F84Lh2lKpvkM3EiOvqqvlOmw93.jpg', 'cast_id': 64, 'character': 'Gloria', 'credit_id': '620408d4194186001ba589e4', 'order': 2}
# ...

# %%
characters_mbti_df = pd.read_csv('../data/Data 8 - Franchise-expanded Movies from Data 2.csv', encoding='unicode_escape')
characters_mbti_df
# Out:
#                           char                   movie  mbti  votes
# 0                Guido Anselmi                   8 1/2  INTP     57
# 1      King Leonidas of Sparta                     300  ENTJ    460
# 2                    Artemisia                     300  ENTJ    127
# 3                       Xerxes                     300  INTJ    103
# 4                        Gorgo                     300  INFJ     62
# ...                        ...                     ...   ...    ...
# 10960                  Gazelle         Zootopia (2016)  ESFP    107
# 10961               Mr Manchas         Zootopia (2016)  ISFJ     40
# 10962              Doug Ramses         Zootopia (2016)  INTP     30
# 10963                   Travis         Zootopia (2016)  ESTP     27
# 10964             Alexis Zorba  Zorba the Greek (1964)  ENFP     39
#
# [10965 rows x 4 columns]

# %%
import re
def remove_spaces(s):
    s = " ".join(s.split())
    if s[0]==' ':
        s = re.sub(r"^\s+", "", s)
    if s[-1]==' ':
        re.sub(r"\s+$", "", s)
    return s

# %%
# recorded_chars = []
# recorded_movies = []
# missing_chars = []
# missing_movies = []
# characters_mbti_df['char'] = characters_mbti_df['char'].str.lower()
# characters_mbti_df['movie'] = characters_mbti_df['movie'].str.lower()

# def char_mbti_search(char_find, movie_find):
#     bool_series = characters_mbti_df['char'].str.contains(char_find) & characters_mbti_df['movie'].str.contains(movie_find)
#     if bool_series.any():
#         index = bool_series.idxmax()  # Or use bool_series[bool_series].index for all matches
#         # print(index)
#         recorded_chars.append(char_find)
#         recorded_movies.append(movie_find)
#         return characters_mbti_df.loc[index]  
#     else:
#         # print(f"No match found for character '{char_find}' in movie '{movie_find}'")
#         missing_chars.append(char_find)
#         missing_movies.append(movie_find)
#         return None


# # char_list = list(try_df['character'])
# # movie_list = list(try_df['movie'])
# # print(char_list)

# # char_list = 'Tony'
# # movie_list = 'Iron Man'

# # print(char_mbti_search('Gazelle', 'Zootopia'))

# import re
# def remove_spaces(s):
#     s = " ".join(s.split())
#     if s[0]==' ':
#         s = re.sub(r"^\s+", "", s)
#     if s[-1]==' ':
#         re.sub(r"\s+$", "", s)
#     return s

# for i in range(len(response_details_merge)):
#     char_i = remove_spaces(str(response_details_merge['character'][i]).lower())
#     movie_i = remove_spaces(str(response_details_merge['movie'][i]).lower())

#     try:
#         movie_split = movie_i.split(' (', maxsplit=1)
#         movie_i = movie_split[0]
#     except:
#         pass
    
#     print((char_i, movie_i))
#     char_mbti_search(char_i, movie_i)

# %%
# char_list = "poulain"
# movie_list = "Amélie"

# char_list = "wall-e"
# movie_list = "WALLÂ·E"

# char_list = "Haku"
# movie_list = "Spirited Away"

# print(char_mbti_search(char_list.lower(), movie_list.lower()))

# %%
# print("found: ", len(recorded_chars))
# print("not found:", len(missing_chars))
# Out:
# found:  659
# not found: 46

# %%
# for i in range(len(recorded_chars)):
#     print(recorded_chars[i], "  from  ", recorded_movies[i])

# %%
# for i in range(len(missing_chars)):
#     print(missing_chars[i], "  from  ", missing_movies[i])

# %%
characters_mbti_df['char'] = characters_mbti_df['char'].str.lower()
characters_mbti_df['movie'] = characters_mbti_df['movie'].str.lower()

with_char_mbti = response_details_merge.copy()

def get_char_mbti(char, movie):
    bool_series_charmbti = characters_mbti_df['char'].str.contains(char) & characters_mbti_df['movie'].str.contains(movie)
    if bool_series_charmbti.any():
        index = bool_series_charmbti.idxmax()
        return characters_mbti_df.loc[index, 'mbti']  
    else:
        return None
    

for i in range(len(with_char_mbti)):
    char = remove_spaces(str(with_char_mbti['character'][i]).lower())
    movie = remove_spaces(str(with_char_mbti['movie'][i]).lower())

    with_char_mbti.loc[i, 'char_mbti'] = get_char_mbti(char, movie)
# Out:
# C:\Users\Marco\AppData\Local\Temp\ipykernel_27772\1767818887.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bool_series_charmbti = characters_mbti_df['char'].str.contains(char) & characters_mbti_df['movie'].str.contains(movie)
# C:\Users\Marco\AppData\Local\Temp\ipykernel_27772\1767818887.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bool_series_charmbti = characters_mbti_df['char'].str.contains(char) & characters_mbti_df['movie'].str.contains(movie)
# C:\Users\Marco\AppData\Local\Temp\ipykernel_27772\1767818887.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bool_series_charmbti = characters_mbti_df['char'].str.contains(char) & characters_mbti_df['movie'].str.contains(movie)

# %%
with_char_mbti.dropna(axis='rows', ignore_index=True)
# Out:
#      person_id person_mbti         character  \
# 0            0        ENFP        Tony Stark
# 1            0        ENFP    Rocket Raccoon
# 2            0        ENFP   Captain America
# 3            0        ENFP      Peter Parker
# 4            0        ENFP       Hobie Brown
# ..         ...         ...               ...
# 651        123        ENFP       Agent Smith
# 652        123        ENFP  Daniel Plainview
# 653        123        ENFP          The Baby
# 654        123        ENFP   Patrick Bateman
# 655        123        ENFP        Raoul Duke
#
#                                    movie          genre_ids  movie_id  \
# 0                      Avengers: Endgame      [12, 878, 28]    299534
# 1         Guardians of the Galaxy Vol. 3      [878, 12, 28]    447365
# 2                      Avengers: Endgame      [12, 878, 28]    299534
# 3              Spider-Man: Far From Home      [28, 12, 878]    429617
# ...

# %%
with_char_mbti.to_csv('../data/Data 9 - Final Dataset.csv')
