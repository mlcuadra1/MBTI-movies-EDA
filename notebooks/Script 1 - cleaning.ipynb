# %% [markdown]
# # Dataset Cleaning
# *(This notebook was inspired by Anton T. Ruberts' Dataset Cleaning notebook.)*
# This dataset is my own collected data from surveys.
#
# Since the table width is not too large, I decided to clean up the columns via Excel.
#
# The main objectives of this notebook are:
# - Observe the contents of the dataset,
# - melt the columns for characters and movies,
# - separate data with proper separator from those with improper formatting,
# - remove empty entries,
# - export the cleaned data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('../data/Data - movies_MBTI_raw.csv')
df.head(-10)
# Out:
#               timestamp                                  username   consent  \
# 0    4/29/2024 15:45:45                               deadpool123  I agree.
# 1    4/29/2024 19:59:03  GBDymrBKBcsRMqef9Nyx#Kn#3LiihcF7#&ghPx!M  I agree.
# 2     4/30/2024 4:57:43                              Lady-Orpheus  I agree.
# 3     4/30/2024 5:41:28                               gyattman123  I agree.
# 4     4/30/2024 8:07:45                                      Hiii  I agree.
# ..                  ...                                       ...       ...
# 108    05/04/2024 13:26                                    SDRS13  I agree.
# 109    05/04/2024 15:17                              97hbjcdtrd56  I agree.
# 110    05/04/2024 17:16                                 philio756  I agree.
# 111    05/04/2024 18:06                                    v453v3  I agree.
# 112     05/05/2024 2:57                         GenericUsername69  I agree.
#
#                      age_confirmation  mbti                     mbti_test  \
# 0    Yes, I am at least 18 years old.  ENFP              michaelcaloz.com
# 1    Yes, I am at least 18 years old.  INTP               16Personalities
# 2    Yes, I am at least 18 years old.  INFP                        Truity
# 3    Yes, I am at least 18 years old.  ENTP              all of the above
# 4    Yes, I am at least 18 years old.  ENFJ                     Sakinorva
# ..                                ...   ...                           ...
# 108  Yes, I am at least 18 years old.  INFJ               16Personalities
# 109  Yes, I am at least 18 years old.  INFJ  academic setting - MBTI test
# 110  Yes, I am at least 18 years old.  INFJ               16Personalities
# 111  Yes, I am at least 18 years old.  INFP               16Personalities
# 112  Yes, I am at least 18 years old.  ISTP                     Sakinorva
#
#                                          char_movie1  \
# 0                      Tony Stark//Avengers: Endgame
# 1      Puss in Boots // Puss in Boots: The Last Wish
# 2    Waymond Wang//Everything Everywhere All at Once
# 3                           Blitzo from Helluva Boss
# 4                       Grace Le domas(Ready or Not)
# ..                                               ...
# 108                          Richie Tozier/IT (2017)
# 109                         Yoda/Empire Strikes Back
# 110                            Hermoine Harry Potter
# 111                       Chloe Beale//Pitch Perfect
# 112                       Postal Dude//Postal (2007)
#
#                                            char_movie2  \
# 0                   Captain America//Avengers: Endgame
# 1                 J. Robert Oppenheimer // Oppenheimer
# 2                                  Ellen Ripley//Alien
# 3                         Jay Bilzerian from Big mouth
# 4                                        Jack(Titanic)
# ..                                                 ...
# 108  Susan Pevensie/Chronicles of Narnia: The Lion,...
# 109                             Rick Blaine/Casablanca
# 110                          Darcy Pride and prejudice
# 111                         The Female//Under the Skin
# 112                      John McClane//Die Hard (1988)
#
#                                            char_movie3  \
# 0    Miles Morales//Spider-Man: Across the Spider-V...
# 1                     Johnny English // Johnny English
# 2                                       Wall-E//Wall-E
# 3                                     Howard from TBBT
# 4                                       Wanda (Marvel)
# ..                                                 ...
# 108                          Legolas/Lord of the Rings
# 109                             Theoden/The Two Towers
# 110                              Anastasia - Anastasia
# 111    Violet Evergarden//Violet Evergarden: The Movie
# 112                  Rick Deckard//Blade Runner (1982)
#
#                                            char_movie4  \
# 0     Hobie Brown//Spider-Man: Across the Spider-Verse
# 1            Parzival (Wade Watts) // Ready Player One
# 2                                   Mathilda//Mathilda
# 3                   Saul Goodman from Better Call Saul
# 4                                     Joy (Inside out)
# ..                                                 ...
# 108  Sirius Black/Harry Potter and Order of the Pho...
# 109                                  Jeriba/Enemy Mine
# 110                       Will traynor - Me before you
# 111                         Alita//Alita: Battle Angel
# 112                       Eric Draven//The Crow (1994)
#
#                                  char_movie5  \
# 0    Peter Parker//Spider-Man: Far From Home
# 1               Benoit Blanc // A Knives Out
# 2                          V//V for Vendetta
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 108       Murphy "Murph" Cooper/Interstellar
# 109                                      NaN
# 110                                      NaN
# 111     Izzy//Izzy Gets the Fuck Across Town
# 112                                      NaN
#
#                                          char_movie6  \
# 0                          Bella Baxter//Poor Things
# 1              Dr. Stephen Strange // Doctor Strange
# 2                        Morticia//The Addams Family
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 108  Patrick Stewart/The Perks of Being a Wallflower
# 109                                              NaN
# 110                                              NaN
# 111                       Megan Walsh//Barely Lethal
# 112                                              NaN
#
#                        char_movie7  \
# 0    Jesse Wallace//Before Sunrise
# 1                Neo // The Matrix
# 2           Amelie Poulain//Amelie
# 3                              NaN
# 4                              NaN
# ..                             ...
# 108     Albert Narracott/War Horse
# 109                            NaN
# 110                            NaN
# 111                            NaN
# 112                            NaN
#
#                                            char_movie8  \
# 0                               Celine//Before Sunrise
# 1    Captain Pete "Maverick" Mitchell // Top Gun: M...
# 2    Willy Wonka//Charlie and the Chocolate Factory...
# 3                                                  NaN
# 4    CaptaLe Pete "Maverick" Mitceadyll // Tja Hun:...
# ..                                                 ...
# 108                           Jasmine/Alladin (Disney)
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112  CaptaDude//Postal Pete "Maverick" Mitcostalll ...
#
#                                          char_movie9  \
# 0               Peter Parker//The Amazing Spider-Man
# 1               Tony Stark // Avengers: Infinity War
# 2                          Remus Lupin//Harry Potter
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 108  Peter B. Parker/Spiderman: Into the Spiderverse
# 109                                              NaN
# 110                                              NaN
# 111                                              NaN
# 112                                              NaN
#
#                                        char_movie10  \
# 0    Rocket Raccoon//Guardians of the Galaxy Vol. 3
# 1                    Loki // Avengers: Infinity War
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 108                              Hector Rivera/Coco
# 109                                             NaN
# 110                                             NaN
# 111                                             NaN
# 112                                             NaN
#
#                                               comments
# 0                                                  NaN
# 1                                                  NaN
# 2    I'd love to know more about how this data is g...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108  Based on a charting of favorite characters fro...
# 109                                                NaN
# 110                                                NaN
# 111  In case of ambiguity: #2 is Scarlett Johansson...
# 112                                                NaN
#
# [113 rows x 17 columns]

# %% [markdown]
# ## Initial exploration of the data

# %%
print("Dataset shape:", df.shape)
print("Dataset columns:", df.columns)
# Out:
# Dataset shape: (123, 17)
# Dataset columns: Index(['timestamp', 'username', 'consent', 'age_confirmation', 'mbti',
#        'mbti_test', 'char_movie1', 'char_movie2', 'char_movie3', 'char_movie4',
#        'char_movie5', 'char_movie6', 'char_movie7', 'char_movie8',
#        'char_movie9', 'char_movie10', 'comments'],
#       dtype='object')

# %% [markdown]
# **Observations**
# - Some columns are not necessary.
#
# **Actions(s)**
# - Eliminate "consent" and text-id columns.
# - Insert index column as id.

# %%
df_dropped = df.drop(['timestamp', 'username', 'consent', 'age_confirmation', 'comments'], axis = 1)

# Add id column before melting, then rename `index` as `id`
df_dropped.reset_index(inplace=True)
df_dropped.rename(columns = {'index':'id'}, inplace = True)

# %% [markdown]
# ## Get only first row as an example

# %%
marco = df_dropped.head(2)
marco.head()
# Out:
#    id  mbti         mbti_test                                    char_movie1  \
# 0   0  ENFP  michaelcaloz.com                  Tony Stark//Avengers: Endgame
# 1   1  INTP   16Personalities  Puss in Boots // Puss in Boots: The Last Wish
#
#                             char_movie2  \
# 0    Captain America//Avengers: Endgame
# 1  J. Robert Oppenheimer // Oppenheimer
#
#                                          char_movie3  \
# 0  Miles Morales//Spider-Man: Across the Spider-V...
# 1                   Johnny English // Johnny English
#
#                                         char_movie4  \
# 0  Hobie Brown//Spider-Man: Across the Spider-Verse
# 1         Parzival (Wade Watts) // Ready Player One
#
#                                char_movie5  \
# 0  Peter Parker//Spider-Man: Far From Home
# 1             Benoit Blanc // A Knives Out
#
#                              char_movie6                    char_movie7  \
# 0              Bella Baxter//Poor Things  Jesse Wallace//Before Sunrise
# 1  Dr. Stephen Strange // Doctor Strange              Neo // The Matrix
#
#                                          char_movie8  \
# 0                             Celine//Before Sunrise
# 1  Captain Pete "Maverick" Mitchell // Top Gun: M...
#
#                             char_movie9  \
# 0  Peter Parker//The Amazing Spider-Man
# 1  Tony Stark // Avengers: Infinity War
#
#                                      char_movie10
# 0  Rocket Raccoon//Guardians of the Galaxy Vol. 3
# 1                  Loki // Avengers: Infinity War

# %% [markdown]
# ## Melt for each column

# %%
marco_melt = pd.melt(marco, id_vars=['id', 'mbti', 'mbti_test'], var_name='char_entry', value_name='char_movie', col_level=None, ignore_index=True)
marco_melt.drop(['char_entry'], axis=1, inplace=True)
marco_melt
# Out:
#     id  mbti         mbti_test  \
# 0    0  ENFP  michaelcaloz.com
# 1    1  INTP   16Personalities
# 2    0  ENFP  michaelcaloz.com
# 3    1  INTP   16Personalities
# 4    0  ENFP  michaelcaloz.com
# 5    1  INTP   16Personalities
# 6    0  ENFP  michaelcaloz.com
# 7    1  INTP   16Personalities
# 8    0  ENFP  michaelcaloz.com
# 9    1  INTP   16Personalities
# 10   0  ENFP  michaelcaloz.com
# 11   1  INTP   16Personalities
# 12   0  ENFP  michaelcaloz.com
# 13   1  INTP   16Personalities
# 14   0  ENFP  michaelcaloz.com
# 15   1  INTP   16Personalities
# 16   0  ENFP  michaelcaloz.com
# 17   1  INTP   16Personalities
# 18   0  ENFP  michaelcaloz.com
# 19   1  INTP   16Personalities
#
#                                            char_movie
# 0                       Tony Stark//Avengers: Endgame
# 1       Puss in Boots // Puss in Boots: The Last Wish
# 2                  Captain America//Avengers: Endgame
# 3                J. Robert Oppenheimer // Oppenheimer
# 4   Miles Morales//Spider-Man: Across the Spider-V...
# 5                    Johnny English // Johnny English
# 6    Hobie Brown//Spider-Man: Across the Spider-Verse
# 7           Parzival (Wade Watts) // Ready Player One
# 8             Peter Parker//Spider-Man: Far From Home
# 9                        Benoit Blanc // A Knives Out
# 10                          Bella Baxter//Poor Things
# 11              Dr. Stephen Strange // Doctor Strange
# 12                      Jesse Wallace//Before Sunrise
# 13                                  Neo // The Matrix
# 14                             Celine//Before Sunrise
# 15  Captain Pete "Maverick" Mitchell // Top Gun: M...
# 16               Peter Parker//The Amazing Spider-Man
# 17               Tony Stark // Avengers: Infinity War
# 18     Rocket Raccoon//Guardians of the Galaxy Vol. 3
# 19                     Loki // Avengers: Infinity War

# %% [markdown]
# ## Split data

# %%
marco_split = marco_melt
new_info = marco_split['char_movie'].str.split('//', n=1, expand=True)
marco_split['character'] = new_info[0]
marco_split['movie'] = new_info[1]
marco_split.drop(columns=['char_movie'], inplace=True)
marco_split
# Out:
#     id  mbti         mbti_test                          character  \
# 0    0  ENFP  michaelcaloz.com                         Tony Stark
# 1    1  INTP   16Personalities                     Puss in Boots
# 2    0  ENFP  michaelcaloz.com                    Captain America
# 3    1  INTP   16Personalities             J. Robert Oppenheimer
# 4    0  ENFP  michaelcaloz.com                      Miles Morales
# 5    1  INTP   16Personalities                    Johnny English
# 6    0  ENFP  michaelcaloz.com                        Hobie Brown
# 7    1  INTP   16Personalities             Parzival (Wade Watts)
# 8    0  ENFP  michaelcaloz.com                       Peter Parker
# 9    1  INTP   16Personalities                      Benoit Blanc
# 10   0  ENFP  michaelcaloz.com                       Bella Baxter
# 11   1  INTP   16Personalities               Dr. Stephen Strange
# 12   0  ENFP  michaelcaloz.com                      Jesse Wallace
# 13   1  INTP   16Personalities                               Neo
# 14   0  ENFP  michaelcaloz.com                             Celine
# 15   1  INTP   16Personalities  Captain Pete "Maverick" Mitchell
# 16   0  ENFP  michaelcaloz.com                       Peter Parker
# 17   1  INTP   16Personalities                        Tony Stark
# 18   0  ENFP  michaelcaloz.com                     Rocket Raccoon
# 19   1  INTP   16Personalities                              Loki
#
#                                   movie
# 0                     Avengers: Endgame
# 1          Puss in Boots: The Last Wish
# 2                     Avengers: Endgame
# 3                           Oppenheimer
# 4   Spider-Man: Across the Spider-Verse
# 5                        Johnny English
# 6   Spider-Man: Across the Spider-Verse
# 7                      Ready Player One
# 8             Spider-Man: Far From Home
# 9                          A Knives Out
# 10                          Poor Things
# 11                       Doctor Strange
# 12                       Before Sunrise
# 13                           The Matrix
# 14                       Before Sunrise
# 15                    Top Gun: Maverick
# 16               The Amazing Spider-Man
# 17               Avengers: Infinity War
# 18       Guardians of the Galaxy Vol. 3
# 19               Avengers: Infinity War

# %% [markdown]
# ### Missing Data

# %%
data.isna().sum()
# Out:
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# Depression                        0
# Insomnia                          0
# OCD                               0
# Music effects                     8
# dtype: int64

# %% [markdown]
# **Observations**
# - There are different scattered sources of the null values (e.g. age, streaming service, listening while working, etc.), and the majority of the missing values come from the BPM, which was mentioned in the forms to leave blank if the participants weren't sure.
#
# **Outcome(s)**
# - We'll delete the former, and retain the latter, as we'll try to impute it through observations.

# %%
# Drop all rows with missing values except BPM
data_dropped = data.dropna(subset=data.columns.difference(['BPM']))

# Fill BPM missing with median of BPM
data_filled = data_dropped.fillna(data_dropped['BPM'].median())

# Verify if missing values are filled in
# data_filled.isna().sum()

# %%
from scipy.stats import iqr as calc_iqr
def get_outlier_fence(data_column):
    """Returns outlier threshold values

    Args:
        data_column: dataframe column to be observed

    Returns:
        low_threshold, up_threshold: lower and upper threshold values
    """
    iqr = calc_iqr(data_column)
    low_threshold = np.quantile(data_column, 0.25) - 3 * iqr
    up_threshold = np.quantile(data_column, 0.75) + 3 * iqr
    return low_threshold, up_threshold

# %%
age_low_th, age_high_th = get_outlier_fence(data_column=data_filled['Age'])
hrs_low_th, hrs_high_th = get_outlier_fence(data_column=data_filled['Hours per day'])
bpm_low_th, bpm_high_th = get_outlier_fence(data_column=data_filled['BPM'])

df_no_outlier = data_filled[
    (data_filled['Age'] >= age_low_th) & (data_filled['Age'] <= age_high_th) &
    (data_filled['Hours per day'] >= hrs_low_th) & (data_filled['Hours per day'] <= hrs_high_th) &
    (data_filled['BPM'] >= bpm_low_th) & (data_filled['BPM'] <= bpm_high_th)
]

# %%
df_no_outlier.describe()
# Out:
#               Age  Hours per day         BPM     Anxiety  Depression  \
# count  682.000000     682.000000  682.000000  682.000000  682.000000
# mean    23.599707       3.418328  123.079179    5.906891    4.866569
# std      8.818426       2.498598   31.112220    2.763656    3.004245
# min     10.000000       0.000000    0.000000    0.000000    0.000000
# 25%     18.000000       2.000000  105.000000    4.000000    2.000000
# 50%     21.000000       3.000000  120.000000    6.000000    5.000000
# 75%     26.000000       5.000000  140.000000    8.000000    7.000000
# max     58.000000      14.000000  220.000000   10.000000   10.000000
#
#          Insomnia         OCD
# count  682.000000  682.000000
# mean     3.716276    2.680352
# std      3.067127    2.862184
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %% [markdown]
# ## Data Pre-processing Pipeline

# %% [markdown]
# For this coffee dataset, we have a clean dataset such that we do not have to apply a pipeline. Nonetheless, I'm leaving this section here to serve as a template for future projects.

# %%
genres_list = list(df_no_outlier.columns)[10:26]
genre_freq_map = {'Never': 0, 'Rarely': 1, 'Sometimes': 2, 'Very frequently': 3}

binary_list = list(['While working', 'Instrumentalist', 'Composer', 'Exploratory', 'Foreign languages'])
binary_map = {'No': 0, 'Yes': 1}

stream_map = {'Other streaming service': 'Others', 'I do not use a streaming service.': 'None'}

numerical_df = df_no_outlier.copy()
numerical_df[genres_list] = df_no_outlier[genres_list].map(lambda x: genre_freq_map.get(x, x))
numerical_df[binary_list] = df_no_outlier[binary_list].map(lambda x: binary_map.get(x, x))
numerical_df['Primary streaming service'] = df_no_outlier['Primary streaming service'].map(lambda x: stream_map.get(x, x))

numerical_df.to_csv('../data/Data - MHxM cleaned.csv', index=False)

# %%
numerical_df
# Out:
#       Age Primary streaming service  Hours per day  While working  \
# 2    18.0                   Spotify            4.0              0
# 4    18.0                   Spotify            4.0              1
# 5    18.0                   Spotify            5.0              1
# 6    18.0             YouTube Music            3.0              1
# 7    21.0                   Spotify            1.0              1
# ..    ...                       ...            ...            ...
# 731  17.0                   Spotify            2.0              1
# 732  18.0                   Spotify            1.0              1
# 733  19.0                    Others            6.0              1
# 734  19.0                   Spotify            5.0              1
# 735  29.0             YouTube Music            2.0              1
#
#      Instrumentalist  Composer         Fav genre  Exploratory  \
# 2                  0         0  Video game music            0
# 4                  0         0               R&B            1
# 5                  1         1              Jazz            1
# 6                  1         0  Video game music            1
# 7                  0         0             K pop            1
# ..               ...       ...               ...          ...
# 731                1         0              Rock            1
# 732                1         0               Pop            1
# 733                0         1               Rap            1
# 734                1         0         Classical            0
# 735                0         0           Hip hop            1
#
#      Foreign languages    BPM  ...  Frequency [Pop]  Frequency [R&B]  \
# 2                    1  132.0  ...                1                0
# 4                    0  107.0  ...                2                3
# 5                    1   86.0  ...                3                3
# 6                    1   66.0  ...                1                1
# 7                    1   95.0  ...                2                2
# ..                 ...    ...  ...              ...              ...
# 731                  1  120.0  ...                3                0
# 732                  1  160.0  ...                3                0
# 733                  0  120.0  ...                2                2
# 734                  0  170.0  ...                0                0
# 735                  1   98.0  ...                2                3
#
#      Frequency [Rap]  Frequency [Rock]  Frequency [Video game music]  Anxiety  \
# 2                  1                 1                             3      7.0
# 4                  3                 0                             1      7.0
# 5                  3                 3                             0      8.0
# 6                  0                 0                             2      4.0
# 7                  1                 0                             1      5.0
# ..               ...               ...                           ...      ...
# 731                1                 3                             0      7.0
# 732                0                 2                             2      3.0
# 733                2                 1                             1      2.0
# 734                0                 0                             2      2.0
# 735                3                 3                             1      2.0
#
#      Depression  Insomnia  OCD  Music effects
# 2           7.0      10.0  2.0      No effect
# 4           2.0       5.0  9.0        Improve
# 5           8.0       7.0  7.0        Improve
# 6           8.0       6.0  0.0        Improve
# 7           3.0       5.0  3.0        Improve
# ..          ...       ...  ...            ...
# 731         6.0       0.0  9.0        Improve
# 732         2.0       2.0  5.0        Improve
# 733         2.0       2.0  2.0        Improve
# 734         3.0       2.0  1.0        Improve
# 735         2.0       2.0  5.0        Improve
#
# [682 rows x 31 columns]
